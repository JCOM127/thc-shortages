# %% [markdown]
# # Exploratory Data Analysis - Shortage Detection
#
# Use this notebook to experiment with the pipeline inputs and outputs.
#
# 1. Load raw CSV files from `../data/raw`.
# 2. Explore cleaning steps.
# 3. Validate shortage logic proposals before incorporating them into `src`.
